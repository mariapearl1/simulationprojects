# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
'Plots of some function which is undefined at x=0'

# %%
# 100 linearly spaced numbers
x = np.linspace(-5,5,1000)

# the function, which is y = sin(1/x) here
y = np.sin(1/x)

# setting the axes at the centre
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('zero')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

# plot the function
plt.plot(x,y, 'r')
plt.title("sin(1/x) rigorous ocsillation near x->0 so value is undefined at x=0")
# show the plot
plt.show()

# %%
# the function, which is y = (1/x) here
y = (1/x)
plt.plot(x,y, 'r')
plt.title("y=1/x from graph  value is undefined at x=0")
# show the plot
plt.show()

# %%
# the function, which is y = 1/x^4 here
y =1/x**4
plt.plot(x,y, 'r')
plt.title("y=1/x^4 from graph  unbound behaviour")
# show the plot
plt.show()

# %%
# the function, which is y = |x|/x here
y =np.abs(x)/x
plt.plot(x,y, 'r')
plt.title("y=|x|/x from graph  function settles at 2 different point")
# show the plot
plt.show()

# %%
# the function, which is y = cos(x)/x here
y =np.cos(x)/x
plt.plot(x,y, 'r')
plt.title("y=cos(x)/x from graph  value is undefined")
# show the plot
plt.show()
