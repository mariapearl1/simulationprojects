# %%
from sympy import symbols,Eq,solve
y=symbols('y')
eq1=Eq(y+3+8,0) #y+3+8=0
sol=solve(eq1)
sol
# Out:
# [-11]

# %%
from sympy import symbols,Eq,solve
x=symbols('x')
eq1=Eq(x**2-5*x+6,0) #x^2-5x+6=0
sol=solve(eq1)
sol
# Out:
# [2, 3]

# %%
from sympy import *
x=symbols('x')
eq1=Eq(2*x**2+3*x+6,0) #2x^2+3x+6=0
sol=solve(eq1)
init_printing()
sol
# Out:
# ⎡  3   √39⋅ⅈ    3   √39⋅ⅈ⎤
# ⎢- ─ - ─────, - ─ + ─────⎥
# ⎣  4     4      4     4  ⎦

# %%
from sympy import *
x=symbols('x')
eq1=Eq(81*x**3-1,0) #81x^3-1=0
sol=solve(eq1)
init_printing()
sol
# Out:
# ⎡ 2/3     2/3   6 ___       2/3   6 ___  ⎤
# ⎢3       3      ╲╱ 3 ⋅ⅈ    3      ╲╱ 3 ⋅ⅈ⎥
# ⎢────, - ──── - ───────, - ──── + ───────⎥
# ⎣ 9       18       6        18       6   ⎦
