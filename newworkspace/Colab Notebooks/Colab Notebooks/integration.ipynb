# %%
from sympy import *
init_printing(use_unicode=False, wrap_line=False)
x = Symbol('x')
integrate(x**2 + x + 1, x) #integration of x^2+x+1
# Out:
#  3    2
# x    x
# -- + -- + x
# 3    2

# %%
from sympy import * 
x,y = symbols('x y') 
expr=x/(x**2+2*x+1)
integrate(expr, x)
# Out:
#                1
# log(x + 1) + -----
#              x + 1

# %%
from sympy import *
from sympy.abc import a, omega, t
init_printing(use_unicode=False, wrap_line=False, no_global=True)
a = symbols('a', positive=True)
f = E**(-I * omega * t)    
integrate(f, (omega, -a, a))
# Out:
# /     I*a*t      -I*a*t
# |  I*e        I*e
# |- -------- + ---------  for And(t > -oo, t < oo, t != 0)
# <     t           t
# |
# |         2*a                       otherwise
# \
